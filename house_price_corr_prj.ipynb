# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
# ##### Find the most correlating variables in the house_data
# ##### Write the Inference properly related to the relationship between variables
#
# ##### Which are the variables can be considered for estimating the house price.

# %%
## Importing necessary libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Load Data

df = pd.read_csv("D:/TopMentor_DS_course/Correlation Exercise/house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
## Remove Irrelevant Columns

df = df.drop(['id', 'date'], axis=1)

# %%
## Correlation Matrix
corr = df.corr()
corr
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.079532   0.187737     0.284611  0.074710  0.029444
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %%
## Correlation Heatmap

plt.figure(figsize=(14,10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
price_corr = corr['price'].sort_values(ascending=False)
print(price_corr)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# zipcode         -0.053203
# Name: price, dtype: float64

# %% [markdown]
# #### Proper Inference (Very Important for Assignment)
# 🔹 1. sqft_living
#
# ✔ Strong positive relationship
# As living area increases, house price increases significantly.
#
# 👉 Larger usable area directly impacts market value.
#
# 🔹 2. grade
#
# ✔ Strong positive relationship
# Higher construction quality & material grade leads to higher price.
#
# 👉 Grade represents overall house quality → Major pricing factor.
#
# 🔹 3. bathrooms
#
# ✔ Moderate positive relationship
# More bathrooms increase house desirability and price.
#
# 👉 Functional comfort increases property value.
#
# 🔹 4. view & waterfront
#
# ✔ Houses with waterfront or better view have higher price.
#
# 👉 Location aesthetics significantly impact price.
#
# 🔹 5. sqft_lot
#
# ❌ Very weak relationship
# Lot size alone does not strongly impact price.
#
# 👉 Buyers value living space more than open land.
#
# 🔹 6. bedrooms
#
# ⚠ Weak correlation
# More bedrooms do not always mean higher price.
#
# 👉 Bedroom count matters less than total living area.

# %% [markdown]
# #### Variables to Consider for Estimating House Price
#
# ##### ✅ Strong Predictors (Must Include)
#
# sqft_living
#
# grade
#
# sqft_above
#
# bathrooms
#
# sqft_living15
#
# view
#
# waterfront
#
# ##### Moderate Predictors (Optional)
#
# floors
#
# yr_built
#
# lat
#
# condition
#
# ##### ❌ Not Recommended
#
# id
#
# date
#
# zipcode (unless using location-based encoding)
#
# sqft_lot
#
# sqft_lot15
#
# #### Business Insight
#
# ✔ House price is primarily driven by:
#
# Living area
#
# Construction quality (grade)
#
# Bathrooms
#
# Location view
#
# Nearby house living area (sqft_living15)
#
# 💡 Buyers prioritize usable indoor space and quality, not just lot size.
